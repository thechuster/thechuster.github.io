# %% [markdown]
# # Predicting Economies Using World Bank Datasets
#
# Sean McSkeane, Albert Chu, Sonny Liu

# %% [markdown]
# ### Table of Contents

# %% [markdown]
# ### Introduction
#
# Write brief introduction here.

# %% [markdown]
# ### Definitions
#
# Should define some of the terms we will be using GDP.

# %% [markdown]
# ## <center>Data Collection<center>

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn import model_selection
from statsmodels import api as sm
# !pip install folium
import folium
import json
from pandas.io.json import json_normalize
# Out:
# Requirement already satisfied: folium in /opt/conda/lib/python3.7/site-packages (0.10.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.7/site-packages (from folium) (2.10.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from folium) (2.21.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from folium) (0.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.12.0)

# %% [markdown]
# For the purposes of this project, we used data from the World Bank dataset. The World Bank site allowed for us to build a custom dataset by choosing the variables that we wanted. We chose to include variables that we thought could be used a predictors of GDP. We purposely chose more variables than we planned on using as we were unsure of the quality of the data, and which variables were missing values.

# %%
worldBankDevInc = pd.read_csv("WorldBankData/data.csv")
worldCountries = pd.read_json("world-countries.json")

worldBankDevInc.dropna(inplace=True)
countryName = ""
first = True
newRows = []
countriesData = []

for index, row in worldBankDevInc.iterrows():
    if (countryName != row["Country Name"]):
        if (first == False):
            #CHOSE WHAT YEARS TO DROP HERE
            df = df.drop(df.loc[:, '1960 [YR1960]':'1990 [YR1990]'].columns, axis = 1)  
            countriesData.append(df)
            # IF YOU WANT TO SEE ALL COUNTRIES DATA UNCOMMENT THIS
            #with pd.option_context('display.max_rows', None, 'display.max_columns', None):
                #display(df)
        countryName = row["Country Name"]
        df = pd.DataFrame(columns=worldBankDevInc.columns) 
        first = False
        
    df = df.append(row, ignore_index=True)

df  = df.drop(df.loc[:, '1960 [YR1960]':'1990 [YR1990]'].columns, axis = 1) 
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #display(df)
    #display(countriesData[206])

# %% [markdown]
# ## <center>Data Processing<center>

# %%
worldData = pd.concat(countriesData)
years = []
GDP = []
counter = 0
year = 1991

for column in worldData:
    if column == str(year) + " [YR" + str(year) + "]":
        GDP += worldData[column].tolist()
        for x in range(7890):
            years.append(year)
        year += 1

for x in range(len(GDP)):
    if GDP[x] == "..":
        GDP[x] = 0

# for x in range(1000):
#     print(GDP[x])
    
# print(len(GDP))
# print(len(years))

scatterPlot = sns.scatterplot(x=years, y=GDP).set_title('Years vs GDP')

# %%
worldData = worldData[["Country Name","Country Code", "Series Name", "Series Code", "2015 [YR2015]"]]

counter = 0
indx = 0
predictors = pd.DataFrame(columns = ["countryName", "Country Code"])
for index, row in worldData.iterrows():
    if row["Country Name"] not in predictors.countryName.values:
        predictors = predictors.append({"countryName": row["Country Name"], "Country Code": row["Country Code"]}, ignore_index=True)
predictors["Current health expenditure (% of GDP)"] = 0.0
predictors["Government expenditure on education, total (% of GDP)"] = 0.0
predictors["Prevalence of undernourishment (% of population)"] = 0.0
predictors["GDP per capita (current US$)"] = 0.0
for index, row in worldData.iterrows():
    if row["Series Name"] in columns:
        counter += 1
        if row["2015 [YR2015]"] != "..":
            predictors.at[indx, row["Series Name"]] = row["2015 [YR2015]"]
        else:
            predictors.at[indx, row["Series Name"]] = np.nan
        if counter % 4 == 0:
            counter = 0
            indx += 1
predictors = predictors.dropna()
predictors
# Out:
#                countryName Country Code  \
# 0              Afghanistan          AFG
# 1                  Albania          ALB
# 7                Argentina          ARG
# 8                  Armenia          ARM
# 10               Australia          AUS
# 11                 Austria          AUT
# 12              Azerbaijan          AZE
# 17                 Belarus          BLR
# 18                 Belgium          BEL
# 19                  Belize          BLZ
# 20                   Benin          BEN
# 26                  Brazil          BRA
# 30            Burkina Faso          BFA
# 32              Cabo Verde          CPV
# 34                Cameroon          CMR
# 40                   Chile          CHL
# 42                Colombia          COL
# 45             Congo, Rep.          COG
# 46              Costa Rica          CRI
# 47           Cote d'Ivoire          CIV
# 51                  Cyprus          CYP
# 52          Czech Republic          CZE
# 55                Dominica          DMA
# 57                 Ecuador          ECU
# 59             El Salvador          SLV
# 62                 Estonia          EST
# 64                Ethiopia          ETH
# 67                 Finland          FIN
# 68                  France          FRA
# 73                 Germany          DEU
# ..                     ...          ...
# 138                  Nepal          NPL
# 139            Netherlands          NLD
# 141            New Zealand          NZL
# 142              Nicaragua          NIC
# 143                  Niger          NER
# 147                 Norway          NOR
# 149               Pakistan          PAK
# 154                   Peru          PER
# 156                 Poland          POL
# 157               Portugal          PRT
# 160                Romania          ROU
# 161     Russian Federation          RUS
# 162                 Rwanda          RWA
# 165  Sao Tome and Principe          STP
# 167                Senegal          SEN
# 168                 Serbia          SRB
# 173        Slovak Republic          SVK
# 174               Slovenia          SVN
# 177           South Africa          ZAF
# 179                  Spain          ESP
# 180              Sri Lanka          LKA
# 187                 Sweden          SWE
# 188            Switzerland          CHE
# 193            Timor-Leste          TLS
# 194                   Togo          TGO
# 197                Tunisia          TUN
# 202                 Uganda          UGA
# 205         United Kingdom          GBR
# 208             Uzbekistan          UZB
# 209                Vanuatu          VUT
#
#      Current health expenditure (% of GDP)  \
# 0                                10.093958
# 1                                 6.819740
# 7                                 8.743315
# 8                                10.117628
# 10                                9.330067
# 11                               10.342885
# 12                                6.839038
# 17                                6.065280
# 18                               10.105638
# 19                                5.884248
# 20                                3.991820
# 26                               11.464734
# 30                                5.825316
# 32                                5.313786
# 34                                4.699523
# 40                                8.299956
# 42                                6.022670
# 45                                3.415351
# 46                                7.780425
# 47                                5.262711
# 51                                6.808545
# 52                                7.242757
# 55                                5.455133
# 57                                8.588457
# 59                                6.864059
# 62                                6.481814
# 64                                3.975932
# 67                                9.742894
# 68                               11.501360
# 73                               11.079066
# ..                                     ...
# 138                               6.219272
# 139                              10.394996
# 141                               9.306624
# 142                               7.915587
# 143                               7.091015
# 147                              10.108893
# 149                               2.687119
# 154                               5.121071
# 156                               6.343389
# 157                               8.971845
# 160                               4.944115
# 161                               5.277003
# 162                               6.519383
# 165                               5.349902
# 167                               5.585687
# 168                               9.405079
# 173                               6.867540
# 174                               8.501741
# 177                               8.197790
# 179                               9.120129
# 180                               3.889920
# 187                              11.008129
# 188                              11.893806
# 193                               3.494244
# 194                               6.249382
# 197                               7.006750
# 202                               6.333950
# 205                               9.792735
# 208                               6.095582
# 209                               4.153229
#
#      Government expenditure on education, total (% of GDP)  \
# 0                                              3.25580
# 1                                              3.43797
# 7                                              5.77611
# 8                                              2.80591
# 10                                             5.32175
# 11                                             5.45675
# 12                                             2.95168
# 17                                             4.78752
# 18                                             6.54091
# 19                                             6.76618
# 20                                             4.35643
# 26                                             6.24106
# 30                                             4.16607
# 32                                             5.26691
# 34                                             2.76805
# 40                                             4.87370
# 42                                             4.47039
# 45                                             4.56147
# 46                                             7.08254
# 47                                             4.82988
# 51                                             6.37530
# 52                                             5.78885
# 55                                             3.38688
# 57                                             4.99870
# 59                                             3.95582
# 62                                             5.13904
# 64                                             4.73792
# 67                                             7.08008
# 68                                             5.46424
# 73                                             4.80518
# ..                                                 ...
# 138                                            3.70359
# 139                                            5.34816
# 141                                            6.33634
# 142                                            4.12553
# 143                                            6.01732
# 147                                            7.55247
# 149                                            2.65002
# 154                                            3.96680
# 156                                            4.81766
# 157                                            4.88294
# 160                                            3.10676
# 161                                            3.83340
# 162                                            3.75146
# 165                                            3.89812
# 167                                            5.45638
# 168                                            4.04069
# 173                                            4.63557
# 174                                            4.91156
# 177                                            5.95619
# 179                                            4.27239
# 180                                            2.22875
# 187                                            7.54830
# 188                                            5.10057
# 193                                            4.33740
# 194                                            5.10860
# 197                                            6.59921
# 202                                            2.77376
# 205                                            5.60939
# 208                                            7.07882
# 209                                            5.54987
#
#      Prevalence of undernourishment (% of population)  \
# 0                                                28.6
# 1                                                 6.0
# 7                                                 3.6
# 8                                                 3.8
# 10                                                2.5
# 11                                                2.5
# 12                                                2.5
# 17                                                2.5
# 18                                                2.5
# 19                                                8.1
# 20                                                9.9
# 26                                                2.5
# 30                                               20.0
# 32                                               13.0
# 34                                                7.7
# 40                                                3.2
# 42                                                6.5
# 45                                               37.7
# 46                                                5.1
# 47                                               20.4
# 51                                                6.0
# 52                                                2.5
# 55                                                6.5
# 57                                                8.0
# 59                                                9.8
# 62                                                3.0
# 64                                               22.7
# 67                                                2.5
# 68                                                2.5
# 73                                                2.5
# ..                                                ...
# 138                                               9.2
# 139                                               2.5
# 141                                               2.5
# 142                                              16.9
# 143                                              11.6
# 147                                               2.5
# 149                                              20.8
# 154                                               9.5
# 156                                               2.5
# 157                                               2.5
# 160                                               2.5
# 161                                               2.5
# 162                                              35.1
# 165                                               7.1
# 167                                              13.0
# 168                                               5.9
# 173                                               3.7
# 174                                               2.5
# 177                                               5.7
# 179                                               2.5
# 180                                               9.7
# 187                                               2.5
# 188                                               2.5
# 193                                              26.1
# 194                                              17.1
# 197                                               4.4
# 202                                              37.5
# 205                                               2.5
# 208                                               6.4
# 209                                               6.9
#
#      GDP per capita (current US$)
# 0                      578.466353
# 1                     3952.830781
# 7                    13789.060425
# 8                     3607.296697
# 10                   56748.420261
# 11                   44176.671743
# 12                    5500.320497
# 17                    5949.106307
# 18                   40441.052042
# 19                    4883.179011
# 20                     783.963078
# 26                    8814.000987
# 30                     575.314454
# 32                    3043.013984
# 34                    1326.969277
# 40                   13574.171504
# 42                    6175.876030
# 45                    1761.323570
# 46                   11299.136177
# 47                    1426.457845
# 51                   23217.484151
# 52                   17715.616852
# 55                    7597.750446
# 57                    6124.491643
# 59                    3705.577946
# 62                   17412.448673
# 64                     639.304360
# 67                   42494.656624
# 68                   36613.375216
# 73                   41394.658161
# ..                            ...
# 138                    792.552891
# 139                  45175.231893
# 141                  38559.547038
# 142                   2049.851415
# 143                    360.853384
# 147                  74521.569932
# 149                   1356.667731
# 154                   6227.586716
# 156                  12572.321848
# 157                  19252.634954
# 160                   8977.498544
# 161                   9313.787542
# 162                    728.081757
# 165                   1595.861423
# 167                   1218.764246
# 168                   5585.117808
# 173                  16182.303724
# 174                  20887.519640
# 177                   5730.934174
# 179                  25817.386608
# 180                   3843.780672
# 187                  50832.552709
# 188                  82081.597124
# 193                   2585.153878
# 194                    570.680737
# 197                   3859.814436
# 202                    709.021039
# 205                  44472.151701
# 208                   2615.025134
# 209                   2721.635936
#
# [88 rows x 6 columns]

# %%
dataGDP = pd.DataFrame(columns=["Country Name", "Country Code", "GDP2015"])
for index, row in worldData.iterrows():
    if row["Series Name"] == "GDP (current US$)":
        dataGDP = dataGDP.append({"Country Name": row["Country Name"], "Country Code": row["Country Code"], "GDP2015": row["2015 [YR2015]"]}, ignore_index=True)
dataGDP
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                              Albania          ALB
# 2                                              Algeria          DZA
# 3                                       American Samoa          ASM
# 4                                              Andorra          AND
# 5                                               Angola          AGO
# 6                                  Antigua and Barbuda          ATG
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                                Aruba          ABW
# 10                                           Australia          AUS
# 11                                             Austria          AUT
# 12                                          Azerbaijan          AZE
# 13                                        Bahamas, The          BHS
# 14                                             Bahrain          BHR
# 15                                          Bangladesh          BGD
# 16                                            Barbados          BRB
# 17                                             Belarus          BLR
# 18                                             Belgium          BEL
# 19                                              Belize          BLZ
# 20                                               Benin          BEN
# 21                                             Bermuda          BMU
# 22                                              Bhutan          BTN
# 23                                             Bolivia          BOL
# 24                              Bosnia and Herzegovina          BIH
# 25                                            Botswana          BWA
# 26                                              Brazil          BRA
# 27                              British Virgin Islands          VGB
# 28                                   Brunei Darussalam          BRN
# 29                                            Bulgaria          BGR
# ..                                                 ...          ...
# 233                                   IDA & IBRD total          IBT
# 234                                          IDA blend          IDB
# 235                                           IDA only          IDX
# 236                                          IDA total          IDA
# 237                          Late-demographic dividend          LTE
# 238                          Latin America & Caribbean          LCN
# 239  Latin America & Caribbean (excluding high income)          LAC
# 240  Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 241       Least developed countries: UN classification          LDC
# 242                                Low & middle income          LMY
# 243                                         Low income          LIC
# 244                                Lower middle income          LMC
# 245                         Middle East & North Africa          MEA
# 246  Middle East & North Africa (excluding high inc...          MNA
# 247  Middle East & North Africa (IDA & IBRD countries)          TMN
# 248                                      Middle income          MIC
# 249                                      North America          NAC
# 250                                     Not classified          INX
# 251                                       OECD members          OED
# 252                                 Other small states          OSS
# 253                        Pacific island small states          PSS
# 254                          Post-demographic dividend          PST
# 255                           Pre-demographic dividend          PRE
# 256                                       Small states          SST
# 257                                         South Asia          SAS
# 258                            South Asia (IDA & IBRD)          TSA
# 259                                 Sub-Saharan Africa          SSF
# 260         Sub-Saharan Africa (excluding high income)          SSA
# 261          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 262                                Upper middle income          UMC
#
#               GDP2015
# 0    19907111418.9938
# 1    11386931489.7968
# 2    165979277276.907
# 3           661000000
# 4    2811489408.89431
# 5    116193649124.151
# 6    1359194740.74074
# 7    594749285413.212
# 8    10553337672.9872
# 9    2691620111.73184
# 10   1351520093185.79
# 11   381805676697.707
# 12   53074468085.1064
# 13        11792300000
# 14   31125851063.8298
# 15    195078678697.23
# 16         4584150000
# 17   56454734396.5842
# 18    455940347170.37
# 19         1762500450
# 20   8291155880.59505
# 21                 ..
# 22   2059809919.89325
# 23   33000198263.3864
# 24   16211541253.1897
# 25   14420604205.7459
# 26   1802214373741.32
# 27                 ..
# 28   12930394937.8137
# 29   50201314894.5817
# ..                ...
# 233  27954716600642.8
# 234     1024951386304
# 235  1072816242432.06
# 236  2106056291167.09
# 237  18417470784005.1
# 238   5517742948141.7
# 239  4997012843036.87
# 240  5290483965946.01
# 241  960498455546.799
# 242  27169208461257.4
# 243  517632917094.299
# 244  5784352356553.79
# 245  3146224148913.01
# 246  1441623404793.42
# 247  1428813291325.01
# 248  26656489801955.1
# 249  19778113935832.2
# 250                ..
# 251  46870246743538.3
# 252  371473048748.633
# 253  8909228715.17981
# 254  44401372309936.5
# 255  1341325489976.12
# 256  452002546514.191
# 257  2697313887065.75
# 258  2697313887065.75
# 259  1661740323494.26
# 260  1660362619647.97
# 261  1661740323494.26
# 262  20866337272423.2
#
# [263 rows x 3 columns]

# %% [markdown]
# ## <center>Exploratory Analysis and Data Visualization<center>

# %%
#worldCountries 

# NEED COUNTRIES IN dataGDP to match countries in worldCountries.

m = folium.Map(location=[37, -102], zoom_start=5)

#folium.Choropleth(
#    geo_data="world-countries.json",
#    name='choropleth',
#    data=dataGDP,
#    columns=['Country Name', 'GDP2015'],
#    key_on='feature.id',
#    fill_color='YlGn',
#    fill_opacity=0.7,
#    line_opacity=0.2,
#    legend_name='Unemployment Rate (%)'
#).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
worldBankDevInc.describe()
# Out:
#                    Country Name Country Code  \
# count                      7920         7920
# unique                      264          264
# top     South Asia (IDA & IBRD)          TMN
# freq                         30           30
#
#                              Series Name  Series Code 1960 [YR1960]  \
# count                               7920         7920          7920
# unique                                30           30          1627
# top     GDP per capita growth (annual %)  FR.INR.LEND            ..
# freq                                 264          264          6241
#
#        1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  \
# count           7920          7920          7920          7920          7920
# unique          2173          2184          2187          2199          2247
# top               ..            ..            ..            ..            ..
# freq            5682          5671          5667          5660          5608
#
#         ... 2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# count   ...          7920          7920          7920          7920
# unique  ...          6065          6071          6083          6092
# top     ...            ..            ..            ..            ..
# freq    ...          1620          1627          1601          1606
#
#        2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# count           7920          7920          7920          7920          7920
# unique          6089          6031          5976          5576          3903
# top               ..            ..            ..            ..            ..
# freq            1613          1680          1745          2126          3932
#
#        2019 [YR2019]
# count           7920
# unique           690
# top               ..
# freq            7220
#
# [4 rows x 64 columns]

# %% [markdown]
# ## <center>Analysis, Hypothesis Testing, and Machine Learning<center>

# %% [markdown]
# ### Predicting GDP Using Access to Healthcare

# %% [markdown]
# ### Predicting GDP Using Access to Technology

# %% [markdown]
# ### Predicting GDP Using Education

# %% [markdown]
# ### Predicting GDP Using Sanitation

# %% [markdown]
# ### Predicting GDP Using Corruption

# %% [markdown]
# ## <center>Insight and Policy Decision<center>
